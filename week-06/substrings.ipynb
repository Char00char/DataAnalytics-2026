# %%
# Exercise 2.A Using built-in functions
## Lab 1. Working with names – parsing string

test_name = 'John Doe'

# %%
def parse_and_display(name):
 for i in range(len(name)):
    if name[i] == ' ':
     first = name[:i]
     last = name[i+1:]
    
 print(f"Full name: {name}")
 print(f"First name: {first}")
 print(f"Last name: {last}")
 print()

parse_and_display(test_name)

test_list = ['Grace Flores', 'JB Oinonen', 'Ken Penn']

parse_and_display(test_list[0])
parse_and_display(test_list[1])
parse_and_display(test_list[2])

parse_and_display('Charles Palacios')
# Out:
# Full name: John Doe
# First name: John
# Last name: Doe
#
# Full name: Grace Flores
# First name: Grace
# Last name: Flores
#
# Full name: JB Oinonen
# First name: JB
# Last name: Oinonen
#
# Full name: Ken Penn
# First name: Ken
# Last name: Penn
#
# Full name: Charles Palacios
# First name: Charles
# Last name: Palacios
